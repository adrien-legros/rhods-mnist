# %%
# load the best model
from keras.models import load_model
model = load_model('./model/MLP_Keras_e9.h5')

# %%
import numpy as np
x_test = np.load('./cleaned/x_test.npy')

# %%
# prediction
result = model.predict(x_test)
result = np.argmax(result, axis=1)
# Out:
# 875/875 [==============================] - 2s 2ms/step

# %%
# sample predictions
plt.figure(figsize=(15,7))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_test[result==i][0].reshape(28,28), cmap='gray')
    plt.title(f"Predicted: {i}")
plt.show()

# %%
print(x_test.shape)
# Out:
# (28000, 784)
